# %% [markdown]
# M01AB - Anti-inflammatory and antirheumatic products, non-steroids, Acetic acid derivatives and related substances
# M01AE - Anti-inflammatory and antirheumatic products, non-steroids, Propionic acid derivatives
# N02BA - Other analgesics and antipyretics, Salicylic acid and derivatives
# N02BE/B - Other analgesics and antipyretics, Pyrazolones and Anilides
# N05B - Psycholeptics drugs, Anxiolytic drugs
# N05C - Psycholeptics drugs, Hypnotics and sedatives drugs
# R03 - Drugs for obstructive airway diseases
# R06 - Antihistamines for systemic use

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
plt.style.use('seaborn')
import seaborn as sns
import numpy as np
import pandas as pd
# %matplotlib inline
# Out:
# C:\Users\Ibrahim\AppData\Local\Temp\ipykernel_8768\1657060312.py:4: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
yearly = pd.read_csv('Yearly.csv')
monthly= pd.read_csv('CleanDataset.csv')
Weekly= pd.read_csv('Weekly.csv')

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
plt.style.use('seaborn')
import seaborn as sns
import numpy as np
import pandas as pd
# %matplotlib inline
#this wil convert dataset  into weekly monthly and yearlu
def Dailydata(weekly):
    weekly["datum"] = pd.to_datetime(weekly["datum"])
    weekly_summary =weekly.resample('w' ,on='datum').agg({ 'M01AB' :'sum', 'M01AE' : 'sum', 'N02BA' :'sum', 'N02BE' : 'sum', 'N05B' :'sum', 'N05C' : 'sum', 'R03' :'sum','R06' :'sum', 'Temperature' :'mean', 'Dew Point' :'mean', 'Humidity' :'mean',  'Wind Speed' :'mean','Wind Gust' :'mean', 'Pressure' :'mean', 'Precip.' :'mean',  'Condition_int' : 'mean'})
    weekly_summary['datum']=weekly_summary.index  #Weekly 
    return weekly_summary
def Weeklydata(weekly):
    weekly["datum"] = pd.to_datetime(weekly["datum"])
    weekly_summary =weekly.resample('w' ,on='datum').agg({ 'M01AB' :'sum', 'M01AE' : 'sum', 'N02BA' :'sum', 'N02BE' : 'sum', 'N05B' :'sum', 'N05C' : 'sum', 'R03' :'sum','R06' :'sum', 'Temperature' :'mean', 'Dew Point' :'mean', 'Humidity' :'mean',  'Wind Speed' :'mean','Wind Gust' :'mean', 'Pressure' :'mean', 'Precip.' :'mean',  'Condition_int' : 'mean'})
    weekly_summary['datum']=weekly_summary.index   #Weekly 
    return weekly_summary
def Monthlydata(weekly):
    monthly["datum"] = pd.to_datetime(weekly["datum"])
    Monthly_summary =monthly.resample('M' ,on='datum').agg({ 'M01AB' :'sum', 'M01AE' : 'sum', 'N02BA' :'sum', 'N02BE' : 'sum', 'N05B' :'sum', 'N05C' : 'sum', 'R03' :'sum','R06' :'sum', 'Temperature' :'mean', 'Dew Point' :'mean', 'Humidity' :'mean',  'Wind Speed' :'mean','Wind Gust' :'mean', 'Pressure' :'mean', 'Precip.' :'mean',  'Condition_int' : 'mean'})
    weekly_summary['datum']=weekly_summary.index    #monthly
    return Monthly_summary
def Yearlydata(weekly):
    yearly["datum"] = pd.to_datetime(weekly["datum"])
    yearly_summary =yearly.resample('Y' ,on='datum').agg({ 'M01AB' :'sum', 'M01AE' : 'sum', 'N02BA' :'sum', 'N02BE' : 'sum', 'N05B' :'sum', 'N05C' : 'sum', 'R03' :'sum','R06' :'sum', 'Temperature' :'mean', 'Dew Point' :'mean', 'Humidity' :'mean',  'Wind Speed' :'mean','Wind Gust' :'mean', 'Pressure' :'mean', 'Precip.' :'mean',  'Condition_int' :'mean'})
    weekly_summary['datum']=weekly_summary.index    #Yearly
    return yearly_summary


    
def plotgraph(dataset,start_date,end_date):
    dataset['datum'] = pd.to_datetime(dataset['datum'])
    df2 = dataset.query('datum>= @start_date and datum<=@end_date')   #Find Btwn 2 dates
    Date = df2['datum']
    M01AB = df2['M01AB']
    M01AE = df2['M01AE']
    N02BA = df2['N02BA']
    N02BE = df2['N02BE']
    N05B = df2['N05B']
    N05C = df2['N05C']
    R03 = df2['R03']
    R06 = df2['R06']
    plt.rcParams['figure.figsize'] = (14,9)
    plt.rcParams['date.converter'] = 'concise'
    plt.rcParams['date.interval_multiples'] = True
    plt.plot(Date, M01AB, color='tab:purple', label='M01AB')
    plt.plot(Date, M01AE, color='tab:blue', label='M01AE')
    plt.plot(Date, N02BA, color='tab:pink', label='N02BA')
    plt.plot(Date, N02BE, color='tab:red', label='N02BE')
    plt.plot(Date, N05B, color='tab:brown', label='N05BE')
    plt.plot(Date, N05C, color='tab:gray', label='N05C')
    plt.plot(Date, R03, color='tab:cyan', label='R03')
    plt.plot(Date, R06, color='tab:olive', label='R06')
    plt.legend()
    plt.title('Sales ')
    plt.xlabel('Date')
    plt.ylabel('Sales numbers')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show
CleanDataset=pd.read_csv('CleanDataset.csv')
dailydataset=Dailydata(CleanDataset)
plotgraph(dailydataset,'2019-05-01','2019-10-13')
# Out:
# C:\Users\Ibrahim\AppData\Local\Temp\ipykernel_8768\2570225503.py:4: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 64
#      62     plt.show
#      63 CleanDataset=pd.read_csv('CleanDataset.csv')
# ---> 64 dailydataset=Dailydata(CleanDataset)
#      65 plotgraph(dailydataset,'2019-05-01','2019-10-13')
#
# Cell In[3], line 12, in Dailydata(weekly)
#      10 def Dailydata(weekly):
#      11     weekly["datum"] = pd.to_datetime(weekly["datum"])
# ---> 12     weekly_summary =weekly.resample('w' ,on='datum').agg({ 'M01AB' :'sum', 'M01AE' : 'sum', 'N02BA' :'sum', 'N02BE' : 'sum', 'N05B' :'sum', 'N05C' : 'sum', 'R03' :'sum','R06' :'sum', 'Temperature' :'mean', 'Dew Point' :'mean', 'Humidity' :'mean',  'Wind Speed' :'mean','Wind Gust' :'mean', 'Pressure' :'mean', 'Precip.' :'mean',  'Condition_int' : 'mean'})
#      13     weekly_summary['datum']=weekly_summary.index  #Weekly
#      14     return weekly_summary
#
# File ~\AppData\Local\anaconda3\lib\site-packages\pandas\core\resample.py:352, in Resampler.aggregate(self, func, *args, **kwargs)
#     343 @doc(
#     344     _shared_docs["aggregate"],
#     345     see_also=_agg_see_also_doc,
#    (...)
#     349 )
#     350 def aggregate(self, func=None, *args, **kwargs):
# --> 352     result = ResamplerWindowApply(self, func, args=args, kwargs=kwargs).agg()
#     353     if result is None:
#     354         how = func
#
# File ~\AppData\Local\anaconda3\lib\site-packages\pandas\core\apply.py:172, in Apply.agg(self)
#     169     return self.apply_str()
#     171 if is_dict_like(arg):
# --> 172     return self.agg_dict_like()
#     173 elif is_list_like(arg):
#     174     # we require a list, but not a 'str'
#     175     return self.agg_list_like()
#
# File ~\AppData\Local\anaconda3\lib\site-packages\pandas\core\apply.py:496, in Apply.agg_dict_like(self)
#     493     selected_obj = obj._selected_obj
#     494     selection = obj._selection
# --> 496 arg = self.normalize_dictlike_arg("agg", selected_obj, arg)
#     498 if selected_obj.ndim == 1:
#     499     # key only used for output
#     500     colg = obj._gotitem(selection, ndim=1)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\pandas\core\apply.py:619, in Apply.normalize_dictlike_arg(self, how, obj, func)
#     617     if len(cols) > 0:
#     618         cols_sorted = list(safe_sort(list(cols)))
# --> 619         raise KeyError(f"Column(s) {cols_sorted} do not exist")
#     621 aggregator_types = (list, tuple, dict)
#     623 # if we have a dict of any non-scalars
#     624 # eg. {'A' : ['mean']}, normalize all to
#     625 # be list-likes
#     626 # Cannot use func.values() because arg may be a Series
#
# KeyError: "Column(s) ['Condition_int', 'Precip.', 'Wind Gust'] do not exist"

# %%
from sklearn import linear_model
import statsmodels.api as sm
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

x = monthly[['Temperature','Dew Point','Wind Speed','Humidity','Pressure']]
y = monthly['M01AE']  #y true
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)
regr = linear_model.LinearRegression()
regr.fit(x_train, y_train)
print('Intercept: \n', regr.intercept_)#bais
print('Coefficients: \n', regr.coef_)

predictions = regr.predict(x_test)  #y predict

print(predictions)
score = regr.score(x_test, y_test)
print(score)
# xl=mean_squared_error(y_test,predictions)
# print(xl)
# Out:
# Intercept:
#  0.02210020579278732
# Coefficients:
#  [ 0.00187768  0.0021153   0.00090049 -0.00399666  0.00182444]
# [0.08721949 0.07784663 0.16457119 ... 0.11442429 0.23218519 0.12854323]
# 0.03300397988881676

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
dataset = pd.read_csv('Monthly.csv')
x = dataset[['Temperature','Dew Point','Wind Speed','Humidity','Pressure','Condition_int']]
y = dataset['M01AB']  #y true
# 0.13308661206584316 [-0.05841906  0.03431375 -0.03234194 -0.03291897  0.17413198  0.1080927 ]

Y=np.array((y-y.mean())/y.std())
X=x.apply(lambda rec:(rec-rec.mean())/rec.std(),axis=0)
import random
def initialize(dim):
    b=random.random()
    theta=np.random.rand(dim)
    return b,theta
b,theta=initialize(6)
print('Bias: ',b,'Weights: ',theta)
def predict_Y(b,theta,X):
    return b + np.dot(X,theta)

Y_hat=predict_Y(b,theta,X)
Y_hat[0:10]
import math
def get_cost(Y,Y_hat):
    Y_resd=Y-Y_hat
    return np.sum(np.dot(Y_resd.T,Y_resd))/len(Y-Y_resd)

Y_hat=predict_Y(b,theta,X)
get_cost(Y,Y_hat)

def update_theta(x,y,y_hat,b_0,theta_o,learning_rate):
    db=(np.sum(y_hat-y)*2)/len(y)
    dw=(np.dot((y_hat-y),x)*2)/len(y)
    b_1=b_0-learning_rate*db
    theta_1=theta_o-learning_rate*dw
    return b_1,theta_1
print("After initialization -Bias: ",b,"theta: ",theta)
Y_hat=predict_Y(b,theta,X)
b,theta=update_theta(X,Y,Y_hat,b,theta,0.01)
print("After first update -Bias: ",b,"theta: ",theta)
get_cost(Y,Y_hat)

def run_gradient_descent(X,Y,alpha,num_iterations):
    b,theta=initialize(X.shape[1])
    iter_num=0
    gd_iterations_df=pd.DataFrame(columns=['iteration','cost'])
    result_idx=0
    for each_iter in range(num_iterations):
        Y_hat=predict_Y(b,theta,X)
        this_cost=get_cost(Y,Y_hat)
        prev_b=b
        prev_theta=theta
        b,theta=update_theta(X,Y,Y_hat,prev_b,prev_theta,alpha)
        
        if(iter_num%10==0):
            gd_iterations_df.loc[result_idx]=[iter_num,this_cost]
            result_idx=result_idx+1
        iter_num +=1
    print('Final Estimate of b and theta : ',b,theta)
    return gd_iterations_df,b,theta

gd_iterations_df,b,theta=run_gradient_descent(X,Y,alpha=0.001,num_iterations=1000)


gd_iterations_df[0:3000]
def eq():
#     Final Estimate of b and theta :  0.12571207652211783 [-0.0060332  -0.17374036  0.11631381  0.1387106   0.35578446  0.1245894 ]

#     theta_1=-0.0060332
#     theta_2=-0.17374036
#     theta_3=0.11631381
#     theta_4=0.1387106
#     theta_5=0.35578446
#     theta_6=0.1245894
#     b=0.12571207652211783
    theta_1=theta[0]
    theta_2=theta[1]
    theta_3=theta[2]
    theta_4=theta[3]
    theta_5=theta[4]
    theta_6=theta[5]
    h = b + theta_1 * dataset['Temperature'] + theta_2 * dataset['Dew Point'] +theta_3 * dataset['Wind Speed']+theta_4 * dataset['Humidity']+theta_5 * dataset['Pressure']+theta_5 * dataset['Condition_int']
    return h
    
# Value=eq(b,theta)
Value=eq()
print(Value)

from sklearn.metrics import mean_squared_error

# Given values
Y_true =Value # Y_true = Y (original values)

# calculated values
Y_pred = y # Y_pred = Y'

# Calculation of Mean Squared Error (MSE)
z=mean_squared_error(Y_true,Y_pred)
print(z)
total=dataset.shape[0]
print(z/301)
# Out:
# Bias:  0.818987157262936 Weights:  [0.38748466 0.51000618 0.26702406 0.89605424 0.92406609 0.36147867]
# After initialization -Bias:  0.818987157262936 theta:  [0.38748466 0.51000618 0.26702406 0.89605424 0.92406609 0.36147867]
# After first update -Bias:  0.8026074141176768 theta:  [0.36471093 0.48147698 0.24908406 0.86767221 0.92273468 0.35382656]
# Final Estimate of b and theta :  0.09170801026112717 [ 0.37682462 -0.2958795   0.12231583  0.06719411  0.34563475  0.26274717]
# 0      28.903084
# 1      28.648349
# 2      27.615993
# 3      26.944854
# 4      27.918315
#          ...
# 297    27.757814
# 298    28.388993
# 299    27.586398
# 300    27.783473
# 301    27.703299
# Length: 302, dtype: float64
# 81.68141196090005
# 0.2713668171458473

# %%
print(gd_iterations_df,b,theta)
# Out:
#     iteration      cost
# 0         0.0  6.709463
# 1        10.0  6.104414
# 2        20.0  5.570639
# 3        30.0  5.099407
# 4        40.0  4.683067
# ..        ...       ...
# 95      950.0  0.982012
# 96      960.0  0.980458
# 97      970.0  0.978953
# 98      980.0  0.977494
# 99      990.0  0.976081
#
# [100 rows x 2 columns] 0.13308661206584316 [-0.05841906  0.03431375 -0.03234194 -0.03291897  0.17413198  0.1080927 ]

# %%
# %matplotlib inline
plt.plot(gd_iterations_df['iteration'],gd_iterations_df['cost'])
plt.xlabel('Number of iterations')
plt.ylabel('Cost or MSE')
# Out:
# Text(0, 0.5, 'Cost or MSE')

# %%
alpha_df_1,b,theta=run_gradient_descent(X,Y,alpha=0.01,num_iterations=2000)
alpha_df_2,b,theta=run_gradient_descent(X,Y,alpha=0.001,num_iterations=2000)
plt.plot(alpha_df_1['iteration'],alpha_df_1['cost'],label="alpha=0.01")
plt.plot(alpha_df_2['iteration'],alpha_df_2['cost'],label="alpha=0.001")
plt.legend()
plt.ylabel('cost')
plt.xlabel('Number of iterations')
plt.title('Cost Vs. Iterations for different alpha values')
# Out:
# Final Estimate of b and theta :  -8.995245078142915e-16 [-0.29304439 -0.01051374  0.09595274  0.10966199  0.12553557  0.01522734]
# Final Estimate of b and theta :  0.015101132969041321 [-0.16520403 -0.09602663  0.15735344  0.03998427  0.15341919  0.08386801]
# Text(0.5, 1.0, 'Cost Vs. Iterations for different alpha values')

# %%
yearly['Time_Stamp'] = pd.to_datetime(yearly['datum'])

monthly['Time_Stamp'] = pd.to_datetime(monthly['datum'])

print('+' * 100)
row_count, colmn_count = yearly.shape
print(f'This dataset contains {row_count} rows and {colmn_count} columns:')
print('-' * 100)
print(yearly.columns)
print('=' * 100)
print(yearly.describe())
print('=' * 100)
print(yearly.info())
print('=' * 100)
print(yearly.corr())
print('+' * 100)
# Out:
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# This dataset contains 6 rows and 18 columns:
# ----------------------------------------------------------------------------------------------------
# Index(['datum', 'M01AB', 'M01AE', 'N02BA', 'N02BE', 'N05B', 'N05C', 'R03',
#        'R06', 'Temperature', 'Dew Point', 'Humidity', 'Wind Speed',
#        'Wind Gust', 'Pressure', 'Precip.', 'Condition_int', 'Time_Stamp'],
#       dtype='object')
# ====================================================================================================
#              M01AB        M01AE        N02BA         N02BE         N05B  \
# count     6.000000     6.000000     6.000000      6.000000     6.000000
# mean   1622.166667  1143.666667  1264.833333  10076.666667  2983.666667
# std     210.925974   149.376928   303.549941   1845.497187   656.824685
# min    1350.000000   889.000000   806.000000   7714.000000  2321.000000
# 25%    1460.500000  1104.250000  1087.500000   8886.250000  2548.000000
# 50%    1670.000000  1150.000000  1335.500000   9917.000000  2899.000000
# 75%    1736.250000  1254.250000  1519.750000  11429.250000  3126.250000
# max    1894.000000  1295.000000  1526.000000  12436.000000  4150.000000
#
#              N05C          R03          R06  Temperature  Dew Point  \
# count    6.000000     6.000000     6.000000     6.000000   6.000000
# mean   201.333333  1872.333333   966.166667    80.479936  60.947671
# std     40.653003   449.301532   131.007506     0.659010   2.183937
# min    158.000000  1228.000000   767.000000    79.800744  58.482246
# 25%    170.000000  1732.250000   915.500000    79.967431  59.678235
# 50%    194.500000  1833.000000   976.500000    80.494794  60.284318
# 75%    226.500000  1984.000000  1008.250000    80.665234  62.135910
# max    262.000000  2607.000000  1163.000000    81.575595  64.405833
#
#         Humidity  Wind Speed  Wind Gust   Pressure  Precip.  Condition_int
# count   6.000000    6.000000   6.000000   6.000000      6.0       6.000000
# mean   55.765110    9.421874   0.023370  29.514273      0.0       3.206041
# std     2.533841    0.839251   0.031289   0.101635      0.0       0.607805
# min    52.878239    8.446117   0.000000  29.326388      0.0       2.106766
# 25%    53.968361    8.913701   0.003739  29.505303      0.0       3.054938
# 50%    55.324963    9.389425   0.007625  29.527835      0.0       3.346562
# 75%    57.627598    9.607978   0.034782  29.582336      0.0       3.650102
# max    59.151190   10.870321   0.078695  29.605287      0.0       3.727347
# ====================================================================================================
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   datum          6 non-null      object
#  1   M01AB          6 non-null      int64
#  2   M01AE          6 non-null      int64
#  3   N02BA          6 non-null      int64
#  4   N02BE          6 non-null      int64
#  5   N05B           6 non-null      int64
#  6   N05C           6 non-null      int64
#  7   R03            6 non-null      int64
#  8   R06            6 non-null      int64
#  9   Temperature    6 non-null      float64
#  10  Dew Point      6 non-null      float64
#  11  Humidity       6 non-null      float64
#  12  Wind Speed     6 non-null      float64
#  13  Wind Gust      6 non-null      float64
#  14  Pressure       6 non-null      float64
#  15  Precip.        6 non-null      int64
#  16  Condition_int  6 non-null      float64
#  17  Time_Stamp     6 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), float64(7), int64(9), object(1)
# memory usage: 992.0+ bytes
# None
# ====================================================================================================
#                   M01AB     M01AE     N02BA     N02BE      N05B      N05C  \
# M01AB          1.000000  0.847852  0.394696  0.857843 -0.319246 -0.471181
# M01AE          0.847852  1.000000  0.782164  0.903398  0.165997 -0.196796
# N02BA          0.394696  0.782164  1.000000  0.622976  0.578251  0.128220
# N02BE          0.857843  0.903398  0.622976  1.000000  0.115482 -0.088985
# N05B          -0.319246  0.165997  0.578251  0.115482  1.000000  0.836492
# N05C          -0.471181 -0.196796  0.128220 -0.088985  0.836492  1.000000
# R03            0.463292  0.124921 -0.441683  0.389839 -0.369444 -0.049960
# R06            0.404748  0.044930 -0.489657  0.365037 -0.433378 -0.113835
# Temperature   -0.137599 -0.484795 -0.637020 -0.125103 -0.511500 -0.190860
# Dew Point      0.050250 -0.396673 -0.548281 -0.071971 -0.626584 -0.252553
# Humidity       0.144714 -0.338027 -0.529319 -0.071189 -0.649885 -0.240157
# Wind Speed    -0.572850 -0.160944  0.453927 -0.174009  0.732021  0.542842
# Wind Gust     -0.514498 -0.010301  0.555763 -0.178248  0.753835  0.409922
# Pressure       0.617689  0.298154 -0.274717  0.486972 -0.633146 -0.581398
# Precip.             NaN       NaN       NaN       NaN       NaN       NaN
# Condition_int  0.306440 -0.200300 -0.750480 -0.002150 -0.815967 -0.458682
#
#                     R03       R06  Temperature  Dew Point  Humidity  \
# M01AB          0.463292  0.404748    -0.137599   0.050250  0.144714
# M01AE          0.124921  0.044930    -0.484795  -0.396673 -0.338027
# N02BA         -0.441683 -0.489657    -0.637020  -0.548281 -0.529319
# N02BE          0.389839  0.365037    -0.125103  -0.071971 -0.071189
# N05B          -0.369444 -0.433378    -0.511500  -0.626584 -0.649885
# N05C          -0.049960 -0.113835    -0.190860  -0.252553 -0.240157
# R03            1.000000  0.969849     0.428358   0.379225  0.403215
# R06            0.969849  1.000000     0.620560   0.520259  0.477279
# Temperature    0.428358  0.620560     1.000000   0.860871  0.675571
# Dew Point      0.379225  0.520259     0.860871   1.000000  0.948636
# Humidity       0.403215  0.477279     0.675571   0.948636  1.000000
# Wind Speed    -0.732513 -0.648408    -0.128359  -0.243468 -0.383387
# Wind Gust     -0.818243 -0.782900    -0.410116  -0.587031 -0.705168
# Pressure       0.756809  0.826522     0.531301   0.392599  0.300587
# Precip.             NaN       NaN          NaN        NaN       NaN
# Condition_int  0.809911  0.832391     0.613405   0.629920  0.655446
#
#                Wind Speed  Wind Gust  Pressure  Precip.  Condition_int
# M01AB           -0.572850  -0.514498  0.617689      NaN       0.306440
# M01AE           -0.160944  -0.010301  0.298154      NaN      -0.200300
# N02BA            0.453927   0.555763 -0.274717      NaN      -0.750480
# N02BE           -0.174009  -0.178248  0.486972      NaN      -0.002150
# N05B             0.732021   0.753835 -0.633146      NaN      -0.815967
# N05C             0.542842   0.409922 -0.581398      NaN      -0.458682
# R03             -0.732513  -0.818243  0.756809      NaN       0.809911
# R06             -0.648408  -0.782900  0.826522      NaN       0.832391
# Temperature     -0.128359  -0.410116  0.531301      NaN       0.613405
# Dew Point       -0.243468  -0.587031  0.392599      NaN       0.629920
# Humidity        -0.383387  -0.705168  0.300587      NaN       0.655446
# Wind Speed       1.000000   0.909116 -0.682590      NaN      -0.854207
# Wind Gust        0.909116   1.000000 -0.677525      NaN      -0.933092
# Pressure        -0.682590  -0.677525  1.000000      NaN       0.761701
# Precip.               NaN        NaN       NaN      NaN            NaN
# Condition_int   -0.854207  -0.933092  0.761701      NaN       1.000000
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
sns.heatmap(yearly.corr(), robust=True, annot=True, cbar=True)
# Out:
# <AxesSubplot:>

# %%
m1=pd.DataFrame(monthly['Time_Stamp'],monthly['M01AB'],monthly["Temperature"])
Data=pd.DataFrame()
Data["Time_Stamp"]=monthly['Time_Stamp']
Data['M01AB']=monthly['N02BE']
Data["Temperature"]=monthly["Temperature"]

sns.heatmap(Data.corr(), robust=True, annot=True, cbar=True)
# Out:
# <AxesSubplot:>

# %%
import pandas as pd
monthly['Time_Stamp'] = pd.to_datetime(monthly['datum'])
m1=pd.DataFrame(monthly['Time_Stamp'],monthly['N02BA'],monthly["Temperature"])
Data=pd.DataFrame()
Data["Time_Stamp"]=monthly['Time_Stamp']
Data['N02BA']=monthly['N02BA']
Data["Temperature"]=monthly["Temperature"]

sns.heatmap(Data.corr(), robust=True, annot=True, cbar=True)
# Out:
# <AxesSubplot:>

# %%
Data
# Out:
#     Time_Stamp  M01AB  Temperature
# 0   2014-01-05    184    61.202381
# 1   2014-01-12    178    59.402685
# 2   2014-01-19    217    63.822785
# 3   2014-01-26    166    65.287582
# 4   2014-02-02    158    69.563291
# ..         ...    ...          ...
# 297 2019-09-15    167    87.145455
# 298 2019-09-22    247    87.602410
# 299 2019-09-29    331    85.460123
# 300 2019-10-06    246    84.557576
# 301 2019-10-13     94    83.000000
#
# [302 rows x 3 columns]

# %%
Date = yearly['Time_Stamp']
M01AB = yearly['M01AB']
M01AE = yearly['M01AE']
N02BA = yearly['N02BA']
N02BE = yearly['N02BE']
N05B = yearly['N05B']
N05C = yearly['N05C']
R03 = yearly['R03']
R06 = yearly['R06']
plt.rcParams['figure.figsize'] = (14,9)
plt.rcParams['date.converter'] = 'concise'
plt.rcParams['date.interval_multiples'] = True
plt.plot(Date, M01AB, color='tab:purple', label='M01AB')
plt.plot(Date, M01AE, color='tab:blue', label='M01AE')
plt.plot(Date, N02BA, color='tab:pink', label='N02BA')
plt.plot(Date, N02BE, color='tab:red', label='N02BE')
plt.plot(Date, N05B, color='tab:brown', label='N05BE')
plt.plot(Date, N05C, color='tab:gray', label='N05C')
plt.plot(Date, R03, color='tab:cyan', label='R03')
plt.plot(Date, R06, color='tab:olive', label='R06')
plt.legend()
plt.title('Big Pharma Sales')
plt.xlabel('Date')
plt.ylabel('Sales numbers')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
start_date = '2019-09-01'
end_date   = '2019-10-13'
df2 = monthly.query('Time_Stamp >= @start_date and Time_Stamp <= @end_date')


Date = df2['Time_Stamp']

M01AB = df2['M01AB']
M01AE = df2['M01AE']
N02BA = df2['N02BA']
N02BE = df2['N02BE']
N05B = df2['N05B']
N05C = df2['N05C']
R03 = df2['R03']
R06 = df2['R06']
plt.rcParams['figure.figsize'] = (14,9)
plt.rcParams['date.converter'] = 'concise'
plt.rcParams['date.interval_multiples'] = True
plt.plot(Date, M01AB, color='tab:purple', label='M01AB')
plt.plot(Date, M01AE, color='tab:blue', label='M01AE')
plt.plot(Date, N02BA, color='tab:pink', label='N02BA')
plt.plot(Date, N02BE, color='tab:red', label='N02BE')
plt.plot(Date, N05B, color='tab:brown', label='N05BE')
plt.plot(Date, N05C, color='tab:gray', label='N05C')
plt.plot(Date, R03, color='tab:cyan', label='R03')
plt.plot(Date, R06, color='tab:olive', label='R06')
plt.legend()
plt.title('Big Pharma Sales')
plt.xlabel('Date')
plt.ylabel('Sales numbers')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show

country_set = set(df['Country'])

plt.figure()
for country in country_set:
    selected_data = df.loc[df['Country'] == country]
    plt.plot(selected_data['Month'], selected_data['GDPA'], label=country)
     
plt.legend()
plt.show()
# Out:
# {83.0, 84.55757576, 85.0, 85.4601227, 86.76219512, 87.14545455, 87.60240964}

# %%
Weekly['Time_Stamp'] = pd.to_datetime(Weekly['datum'])

fig, ax = plt.subplots(figsize=(10, 10))
Date = Weekly['Time_Stamp']
M01AB = Weekly['M01AB']
M01AE = Weekly['M01AE']
N02BA = Weekly['N02BA']
N02BE = Weekly['N02BE']
N05B = Weekly['N05B']
N05C = Weekly['N05C']
R03 = Weekly['R03']
R06 = Weekly['R06']
# Add x-axis and y-axis
ax.scatter(Date,
         [M01AB] ,
           color='Green')

# Set title and labels for axes
ax.set(xlabel="Date",
       ylabel="Sales",
       title="Time Period")

plt.show()

# %%
columns = yearly.iloc[:, 1:9]
display(columns)
sizes = yearly.sum(axis=0)
sizes.plot.pie()
# Out:
#         datum     M01AB     M01AE     N02BA      N02BE      N05B     N05C  \
# 0  12/31/2014    1350.0    1090.0    1519.0     8886.0    4150.0    262.0
# 1  12/31/2015    1755.0    1288.0    1520.0    11590.0    2878.0    158.0
# 2  12/31/2016    1894.0    1295.0    1526.0    12436.0    2920.0    201.0
# 3  12/31/2017    1680.0    1147.0    1152.0     8887.0    2438.0    164.0
# 4  12/31/2018    1660.0    1153.0    1066.0    10947.0    3195.0    235.0
# 5  12/31/2019    1394.0     889.0     806.0     7714.0    2321.0    188.0
# T         NaN  262791.0  185274.0  204903.0  1632420.0  483354.0  32616.0
#
#         R03       R06
# 0    1228.0     767.0
# 1    1710.0     950.0
# 2    2023.0    1003.0
# 3    1799.0     904.0
# 4    2607.0    1163.0
# 5    1867.0    1010.0
# T  303318.0  156519.0
# C:\Users\Ibrahim\AppData\Local\Temp\ipykernel_4844\571681049.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   sizes = yearly.sum(axis=0)
# <AxesSubplot:ylabel='None'>

# %%
# row_sum = yearly.iloc[:,1:9].sum()
# yearly.tail()
# yearly.loc['T'] = row_sum
# yearly.fillna('')
# yearly.loc['T']
# labels = yearly.columns
# sizes = yearly.iloc[-1].plot.pie()
# plt.savefig('pie_chart.png')

import io
CleanDataset=pd.read_csv('DailyDataset.csv')
columns = CleanDataset.iloc[:, 1:9]
sizes = columns.sum(axis=0)
plt.ion()
plt.clf()

plt.figure(figsize=(8, 5))
sizes.plot.pie()
buf = io.BytesIO()

# Save the figure to the BytesIO object
plt.savefig(buf, format='png')

# Seek to the beginning of the BytesIO object
buf.seek(0)

# Create a Flask Response object
response = Response(buf.getvalue(), mimetype='image/png')
plt.ioff()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 28
#      25 buf.seek(0)
#      27 # Create a Flask Response object
# ---> 28 response = Response(buf.getvalue(), mimetype='image/png')
#      29 plt.ioff()
#
# NameError: name 'Response' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [20], in <cell line: 1>()
# ----> 1 print(fig.plot.pie())
#       2 print(type(fig))
#
# AttributeError: 'function' object has no attribute 'pie'

# %%
Weekly['Time_Stamp'] = pd.to_datetime(Weekly['datum'])

print('+' * 100)
row_count, colmn_count = Weekly.shape
print(f'This dataset contains {row_count} rows and {colmn_count} columns:')
print('-' * 100)
print(Weekly.columns)
print('=' * 100)
print(Weekly.describe())
print('=' * 100)
print(Weekly.info())
print('=' * 100)
print(Weekly.corr())
print('+' * 100)
# Out:
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# This dataset contains 302 rows and 18 columns:
# ----------------------------------------------------------------------------------------------------
# Index(['datum', 'M01AB', 'M01AE', 'N02BA', 'N02BE', 'N05B', 'N05C', 'R03',
#        'R06', 'Temperature', 'Dew Point', 'Humidity', 'Wind Speed',
#        'Wind Gust', 'Pressure', 'Precip.', 'Condition_int', 'Time_Stamp'],
#       dtype='object')
# ====================================================================================================
#             M01AB       M01AE       N02BA       N02BE        N05B        N05C  \
# count  302.000000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean    32.228477   22.721854   25.129139  200.198675   59.278146    4.000000
# std      8.166709    6.621378    7.619254   72.511612   21.357940    3.070598
# min      8.000000    4.000000    3.000000   81.000000   18.000000    0.000000
# 25%     27.000000   19.000000   20.000000  144.000000   44.000000    2.000000
# 50%     32.000000   22.000000   25.000000  191.000000   55.000000    3.000000
# 75%     37.000000   26.750000   30.000000  243.750000   68.000000    5.750000
# max     59.000000   51.000000   50.000000  476.000000  146.000000   17.000000
#
#               R03         R06  Temperature   Dew Point    Humidity  \
# count  302.000000  302.000000   302.000000  302.000000  302.000000
# mean    37.198675   19.195364    80.409670   60.755771   55.584463
# std     22.594363   11.086713     7.991514   13.961087   12.196953
# min      2.000000    1.000000    59.402685   23.476510   21.694611
# 25%     21.000000   11.000000    73.547947   48.908897   46.599943
# 50%     32.000000   17.000000    83.803483   66.079234   57.737075
# 75%     49.750000   25.000000    86.519299   73.083986   65.432515
# max    131.000000   66.000000    93.296970   78.292683   77.174699
#
#        Wind Speed   Wind Gust    Pressure  Precip.  Condition_int
# count  302.000000  302.000000  302.000000    302.0     302.000000
# mean     9.411884    0.023928   29.514953      0.0       3.174300
# std      3.311483    0.120576    0.489917      0.0       1.665706
# min      2.367470    0.000000   25.381677      0.0       0.047619
# 25%      6.635350    0.000000   29.415462      0.0       2.009376
# 50%      9.283844    0.000000   29.651466      0.0       2.975436
# 75%     11.603872    0.000000   29.805113      0.0       4.146289
# max     21.427711    1.177914   30.058110      0.0       8.191083
# ====================================================================================================
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 302 entries, 0 to 301
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   datum          302 non-null    object
#  1   M01AB          302 non-null    int64
#  2   M01AE          302 non-null    int64
#  3   N02BA          302 non-null    int64
#  4   N02BE          302 non-null    int64
#  5   N05B           302 non-null    int64
#  6   N05C           302 non-null    int64
#  7   R03            302 non-null    int64
#  8   R06            302 non-null    int64
#  9   Temperature    302 non-null    float64
#  10  Dew Point      302 non-null    float64
#  11  Humidity       302 non-null    float64
#  12  Wind Speed     302 non-null    float64
#  13  Wind Gust      302 non-null    float64
#  14  Pressure       302 non-null    float64
#  15  Precip.        302 non-null    int64
#  16  Condition_int  302 non-null    float64
#  17  Time_Stamp     302 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(7), int64(9), object(1)
# memory usage: 42.6+ KB
# None
# ====================================================================================================
#                   M01AB     M01AE     N02BA     N02BE      N05B      N05C  \
# M01AB          1.000000  0.187582  0.127931  0.193043 -0.077773 -0.002517
# M01AE          0.187582  1.000000  0.229486  0.392301  0.081574  0.034315
# N02BA          0.127931  0.229486  1.000000  0.291370  0.282820  0.092018
# N02BE          0.193043  0.392301  0.291370  1.000000  0.123120  0.060461
# N05B          -0.077773  0.081574  0.282820  0.123120  1.000000  0.272035
# N05C          -0.002517  0.034315  0.092018  0.060461  0.272035  1.000000
# R03            0.149030  0.209114 -0.026685  0.455763  0.033000  0.147346
# R06            0.076451 -0.119685 -0.183772 -0.418462 -0.218628 -0.079927
# Temperature   -0.009912 -0.233873 -0.219580 -0.536952 -0.195685 -0.100123
# Dew Point      0.030374 -0.160682 -0.189471 -0.474126 -0.151295 -0.094544
# Humidity       0.069644 -0.077133 -0.130463 -0.328668 -0.093521 -0.067190
# Wind Speed    -0.075046 -0.073476 -0.000598 -0.508266  0.020905 -0.085480
# Wind Gust     -0.050350  0.082166  0.175670 -0.001936  0.018203  0.133258
# Pressure       0.073603  0.166891  0.011332  0.408552  0.084706 -0.006538
# Precip.             NaN       NaN       NaN       NaN       NaN       NaN
# Condition_int  0.123376  0.075212 -0.101622  0.098348  0.011865  0.019693
#
#                     R03       R06  Temperature  Dew Point  Humidity  \
# M01AB          0.149030  0.076451    -0.009912   0.030374  0.069644
# M01AE          0.209114 -0.119685    -0.233873  -0.160682 -0.077133
# N02BA         -0.026685 -0.183772    -0.219580  -0.189471 -0.130463
# N02BE          0.455763 -0.418462    -0.536952  -0.474126 -0.328668
# N05B           0.033000 -0.218628    -0.195685  -0.151295 -0.093521
# N05C           0.147346 -0.079927    -0.100123  -0.094544 -0.067190
# R03            1.000000 -0.083471    -0.306231  -0.309083 -0.254874
# R06           -0.083471  1.000000     0.596545   0.501634  0.309014
# Temperature   -0.306231  0.596545     1.000000   0.889254  0.623235
# Dew Point     -0.309083  0.501634     0.889254   1.000000  0.907028
# Humidity      -0.254874  0.309014     0.623235   0.907028  1.000000
# Wind Speed    -0.412172  0.385240     0.562638   0.601731  0.504423
# Wind Gust     -0.082650 -0.021504    -0.110488  -0.135240 -0.130103
# Pressure       0.316740 -0.309458    -0.392461  -0.411996 -0.350269
# Precip.             NaN       NaN          NaN        NaN       NaN
# Condition_int  0.081903 -0.236387    -0.150724   0.039515  0.227680
#
#                Wind Speed  Wind Gust  Pressure  Precip.  Condition_int
# M01AB           -0.075046  -0.050350  0.073603      NaN       0.123376
# M01AE           -0.073476   0.082166  0.166891      NaN       0.075212
# N02BA           -0.000598   0.175670  0.011332      NaN      -0.101622
# N02BE           -0.508266  -0.001936  0.408552      NaN       0.098348
# N05B             0.020905   0.018203  0.084706      NaN       0.011865
# N05C            -0.085480   0.133258 -0.006538      NaN       0.019693
# R03             -0.412172  -0.082650  0.316740      NaN       0.081903
# R06              0.385240  -0.021504 -0.309458      NaN      -0.236387
# Temperature      0.562638  -0.110488 -0.392461      NaN      -0.150724
# Dew Point        0.601731  -0.135240 -0.411996      NaN       0.039515
# Humidity         0.504423  -0.130103 -0.350269      NaN       0.227680
# Wind Speed       1.000000   0.096640 -0.413575      NaN      -0.101828
# Wind Gust        0.096640   1.000000 -0.068065      NaN      -0.155498
# Pressure        -0.413575  -0.068065  1.000000      NaN       0.007793
# Precip.               NaN        NaN       NaN      NaN            NaN
# Condition_int   -0.101828  -0.155498  0.007793      NaN       1.000000
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
